# %% [markdown]
# # Iris Flower Classification

# %% [markdown]
# ## Understanding The Problem

# %% [markdown]
# #### Iris flower has three species; setosa, versicolor, and virginica, which differs according to their measurements. Now assume that you have the measurements of the iris flowers according to their species, and here your task is to train a machine learning model that can learn from the measurements of the iris species and classify them.

# %% [markdown]
# #### Although the Scikit-learn library provides a dataset for iris flower classification, you can also download the same dataset from here for the task of iris flower classification with Machine Learning

# %% [markdown]
# ### Image of our Species

# %%
from IPython.display import Image
Image(url='https://editor.analyticsvidhya.com/uploads/51518iris%20img1.png', width=500)
# Out:
# <img src="https://editor.analyticsvidhya.com/uploads/51518iris%20img1.png" width="500"/>

# %% [markdown]
# ## Data Extraction

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv("Iris.csv")
dataset.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ## Data Cleaning

# %%
dataset.shape
# Out:
# (150, 6)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
dataset.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
dataset.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Histogram

# %%
plt.title("Histogram of Sepal Length of Flower dataset")
plt.hist(dataset['SepalLengthCm'], color = 'brown', edgecolor = 'black')
plt.show()

# %%
plt.title("Histogram of Sepal Width of Flower dataset")
plt.hist(dataset['SepalWidthCm'], color = "brown", edgecolor = 'black')
plt.show()

# %%
plt.title("Histogram of Petel Length of Flower dataset")
plt.hist(dataset['PetalLengthCm'], color = 'skyblue', edgecolor = 'black')
plt.show()

# %%
plt.title("Histogram of Petal Width of Flower dataset")
plt.hist(dataset['PetalWidthCm'], color = 'skyblue', edgecolor = 'black')
plt.show()

# %% [markdown]
# ### Scatterplot

# %%
color = ['red', 'teal', 'indigo']
species=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
for i in range(3):
    x = dataset[dataset['Species'] == species[i]]
    plt.scatter(x['SepalLengthCm'], x['SepalWidthCm'], c = color[i], label = species[i])
plt.title("Graph of Sepal Length and Sepal Width")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.legend()

# %%
for i in range(3):
    x = dataset[dataset['Species'] == species[i]]
    plt.scatter(x['PetalLengthCm'], x['PetalWidthCm'], c = color[i], label = species[i])
plt.title("Graph of Petal Length and Petal Width")
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.legend()

# %%
for i in range(3):
    x = dataset[dataset['Species'] == species[i]]
    plt.scatter(x['SepalLengthCm'], x['PetalWidthCm'], c = color[i], label = species[i])
plt.title("Graph of Sepal Length and Petal Width")
plt.xlabel("Sepal Length")
plt.ylabel("Petal Width")
plt.legend()

# %%
for i in range(3):
    x = dataset[dataset['Species'] == species[i]]
    plt.scatter(x['PetalLengthCm'], x['SepalWidthCm'], c = color[i], label = species[i])
plt.title("Graph of Petal Length and Sepal Width")
plt.xlabel("Petal Length")
plt.ylabel("Sepal Width")
plt.legend()

# %% [markdown]
# ### Density Plots

# %%
sns.distplot(dataset.SepalLengthCm, color = 'maroon')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Density'>

# %%
sns.distplot(dataset.SepalWidthCm, color = 'maroon')
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Density'>

# %%
sns.distplot(dataset.PetalLengthCm, color = 'maroon')
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Density'>

# %%
sns.distplot(dataset.PetalWidthCm, color = 'maroon')
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='Density'>

# %% [markdown]
# ### Violin Plot

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x = 'Species', y = 'SepalLengthCm', data = dataset)
plt.subplot(2,2,2)
sns.violinplot(x = 'Species', y = 'SepalWidthCm', data = dataset)
plt.subplot(2,2,3)
sns.violinplot(x = 'Species', y = 'PetalLengthCm', data = dataset)
plt.subplot(2,2,4)
sns.violinplot(x = 'Species', y = 'PetalWidthCm', data = dataset)
# Out:
# <Axes: xlabel='Species', ylabel='PetalWidthCm'>

# %% [markdown]
# ### Heatmap

# %%
numeric_columns = dataset.drop(columns = 'Species', axis = 1)
numeric_columns
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
sns.heatmap(numeric_columns.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()
label
# Out:
# LabelEncoder()

# %%
label.fit_transform(dataset['Species'])
dataset['Species'] = label.fit_transform(dataset['Species'])
dataset
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %%
dataset.Species.unique()
# Out:
# array([0, 1, 2])

# %%
X = dataset.drop(columns = 'Species', axis = 1)
Y = dataset['Species']

# %%
X
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
Y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Species, Length: 150, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 20)

# %%
print(f"X_train Shape is : {X_train.shape}")
print(f"X_test Shape is : {X_test.shape}")
print(f"Y_train Shape is : {Y_train.shape}")
print(f"Y_test Shape is : {Y_test.shape}")
# Out:
# X_train Shape is : (105, 5)
# X_test Shape is : (45, 5)
# Y_train Shape is : (105,)
# Y_test Shape is : (45,)

# %% [markdown]
# ## Incorporating Machine Learning Algorithms

# %% [markdown]
# ### Using Various Classifiers

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score,precision_score

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, BaggingClassifier, ExtraTreesClassifier, GradientBoostingClassifier

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()
xgb = XGBClassifier(n_estimators =50, random_state = 2)
lr = LogisticRegression(solver = 'liblinear', penalty = 'l1')
svc = SVC(kernel = 'sigmoid', gamma = 1.0)
dtc = DecisionTreeClassifier(max_depth = 5)
knc = KNeighborsClassifier()
rfc = RandomForestClassifier(n_estimators = 50, random_state = 2)
abc = AdaBoostClassifier(n_estimators = 50, random_state = 2)
bc = BaggingClassifier(n_estimators = 50, random_state = 2)
etc = ExtraTreesClassifier(n_estimators = 50, random_state = 2)
gbc = GradientBoostingClassifier(n_estimators = 50, random_state = 2)

# %%
classifiers = {
    'GNB' : gnb,
    'MNB' : mnb,
    'BNB' : bnb,
    'XGB' : xgb,
    'LR' : lr,
    'SVC' : svc,
    'DTC' : dtc,
    'KNC' : knc,
    'RFC' : rfc,
    'ABC' : abc,
    'BC' : bc,
    'ETC' : etc,
    'GBC' : gbc
}

# %%
def train_classifier(clf, X_train, Y_train, X_test, Y_test):
    clf.fit(X_train, Y_train)
    prediction = clf.predict(X_test)
    accuracy = accuracy_score(Y_test, prediction)
    precision = precision_score(Y_test, prediction, average = 'weighted')

    return accuracy, precision

# %%
accuracy_scores = []
precision_scores = []

# %%
from sklearn.metrics import classification_report

# %% [markdown]
# ## Testing the Models

# %%
for name, clf in classifiers.items():
    current_accuracy, current_precision = train_classifier(clf, X_train, Y_train, X_test, Y_test)

    print("For ",name)
    print(f"Accuracy Score is :  {current_accuracy * 100}%")
    print(f"Precision Score is : {current_precision * 100}%\n")
    print(f"Classification Report is :\n {classification_report(Y_test, clf.predict(X_test))}")
    print("\n\n")

    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# For  GNB
# Accuracy Score is :  95.55555555555556%
# Precision Score is : 96.00000000000001%
#
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       0.90      1.00      0.95        18
#            2       1.00      0.86      0.92        14
#
#     accuracy                           0.96        45
#    macro avg       0.97      0.95      0.96        45
# weighted avg       0.96      0.96      0.96        45
#
#
#
#
# For  MNB
# Accuracy Score is :  86.66666666666667%
# Precision Score is : 88.95572263993317%
#
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96        13
#            1       0.93      0.72      0.81        18
#            2       0.74      1.00      0.85        14
#
#     accuracy                           0.87        45
#    macro avg       0.89      0.88      0.87        45
# ...
